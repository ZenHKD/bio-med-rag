# %%
import pandas as pd 
import numpy as np
import json
import ast
from tqdm import tqdm

import sys, os
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

from scripts.query import *
# Out:
# Skipping import of cpp extensions due to incompatible torch version 2.10.0+cu128 for torchao version 0.15.0             Please see https://github.com/pytorch/ao/issues/2919 for more info

# %%
data_path = os.path.join(project_root, 'data')

medmcqa = os.path.join(data_path, 'processed', 'medmcqa', 'medmcqa.json')

with open(medmcqa, 'r') as f:
    json_file = json.load(f)

df = pd.DataFrame(json_file)

df['llm_answer'] = ''

# %%
rag = Bio_RAG()

# %%
for i in tqdm(range(len(df.head(10))), desc = 'Querying'):
    df.loc[i, 'llm_answer'] = rag.chat(df.loc[i, 'question'])
# Out:
# ...
# Querying:  90%|█████████ | 9/10 [00:53<00:05,  5.95s/it]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[5], line 2
#       1 for i in tqdm(range(len(df.head(10))), desc = 'Querying'):
# ----> 2     df.loc[i, 'llm_answer'] = rag.chat(df.loc[i, 'question'])
#
# File ~/bio-med-rag/scripts/query.py:83, in Bio_RAG.chat(self, question, k)
#      81 def chat(self, question, k = 5):
# ---> 83     chunks = self.retrieve(question, k, device)
#      84     context = "\n\n".join(c["text"] for c in chunks)
#      85     answer = self.call_llm(context, question, max_tokens=2)
#
# File ~/bio-med-rag/scripts/query.py:54, in Bio_RAG.retrieve(self, question, k, device)
#      51     docs = json.load(f)
#      53 index = faiss.read_index(os.path.join(VECTORSTORE_DIR, INDEX_FILE))
# ---> 54 q_vec = self.embed_question(question, device)
# ...

# %%
df.head(10)
# Out:
#                                             question answer llm_answer
# 0  Which of the following is not true for myelina...      A         D.
# 1  Which of the following is not true about glome...      A    Answer:
# 2  A 29 yrs old woman with a pregnancy of 17 week...      C         D.
# 3  Axonal transport is:\n\nA. Antegrade\nB. Retro...      C         C.
# 4  Low insulin to glucagon ratio is seen in all o...      A         D.
# 5  Concentration of tropicamide:\n\nA. 0.01\nB. 0...      A         B.
# 6  Which of the following statements is true rega...      A    Answer:
# 7  Which of the following are not a branch of ext...      B         D.
# 8  Diagnosis of the following ECG-\n\nA. Ventricu...      B         B.
# 9  A blue new born presents with cyanosis. The X–...      B
